# %%
print("Hello IT101B !")
print("I hope you are going to have fun")
# Out:
# Hello IT101B !
# I hope you are going to have fun

# %%
print(2+2)
# Out:
# 4

# %%
print("2+2")
# Out:
# 2+2

# %%
print("2+2 = ",2+2)
print("2+3 = ",2+3)
print("2+4 = ",2+4)
print("2+5 = ",2+5)
# Out:
# 2+2 =  4
# 2+3 =  5
# 2+4 =  6
# 2+5 =  7

# %%
x = 1.2

# %%
print(x)
# Out:
# 1.2

# %%
type(x)
# Out:
# float

# %%
5%3
# Out:
# 2

# %%
x = 1
y = x

# %%
y = 2

# %%
print(x)
# Out:
# 1

# %%
1+2
# Out:
# 3

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
print("hello")
# Out:
# hello

# %%
for x in [1,2,3,4,5,6,7,8,9]:
    print("7 *",x,"=",7*x)
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
