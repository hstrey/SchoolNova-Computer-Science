# %%
import random

# %%
l = ["one","two","three"]

# %%
random.choice(l)
# Out:
# 'two'

# %%
for i in range(10):
    print(random.choice(l))
# Out:
# two
# three
# two
# three
# two
# two
# one
# one
# two
# three

# %%
class Dice:
    
    def __init__(self,sides):
        self.sides = sides
        
    def roll(self):
        return random.choice(self.sides)

# %%
sixsided = Dice([1,2,3,4,5,6])

# %%
for i in range(10):
    print(sixsided.roll())
# Out:
# 3
# 4
# 2
# 2
# 5
# 3
# 6
# 6
# 5
# 4

# %%
literal = Dice(["one","two","three","four","five","six"])

# %%
for i in range(10):
    print(literal.roll())
# Out:
# two
# five
# four
# five
# four
# three
# five
# three
# five
# three

# %%
class Dice:
    
    def __init__(self,sides):
        self.sides = sides
        self.roll()
        
    def __str__(self):
        return str(self.__value)
    
    def get_value(self):
        return self.__value
        
    def roll(self):
        self.__value = random.choice(self.sides)
        return self.__value
    
    def set_value(self,newvalue):
        print("Bad! You should never change the value of the dice")

# %%
myDie = Dice(range(1,7))

# %%
print(myDie)
print(myDie.value)
print(myDie.get_value())
myDie.value = 6
# Out:
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-3e63836eb177> in <module>
#       1 print(myDie)
# ----> 2 print(myDie.value)
#       3 print(myDie.get_value())
#       4 myDie.value = 6
#
# AttributeError: 'Dice' object has no attribute 'value'

# %%
print(myDie.get_value())
myDie.set_value(6)
# Out:
# 5
# Bad! You should never change the value of the dice

# %%
print(myDie)
# Out:
# 5

# %%
print(myroll)
# Out:
# 5

# %%
myDie.__value = 6

# %%
print(myDie)
# Out:
# 4

# %%
# let's try something cool.  We want to create a list
# of dice.  The idea is that you have a cup full of
# different dice and then you pick one of those and roll it
dice_list = [Dice([1,2,3]),Dice([1,2,3,4,5,6]),Dice([9])]

# %%
DieOfDice = Dice(dice_list)

# %%
for i in range(10):
    DieOfDice.roll()
    print(DieOfDice.get_value().roll())
# Out:
# 9
# 6
# 5
# 1
# 2
# 1
# 9
# 2
# 1
# 1
